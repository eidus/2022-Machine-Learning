# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### data preprocessing

# %%
# 다운로드
data20 = pd.read_csv("C:\\Users\\rladb\\Desktop\\2022년 2학기\\머신러닝\\ML_Project\\2020_LoL_esports_match_data_from_OraclesElixir_20221210.csv")
data21 = pd.read_csv("C:\\Users\\rladb\\Desktop\\2022년 2학기\\머신러닝\\ML_Project\\2021_LoL_esports_match_data_from_OraclesElixir_20221210.csv")
data22 = pd.read_csv("C:\\Users\\rladb\\Desktop\\2022년 2학기\\머신러닝\\ML_Project\\2022_LoL_esports_match_data_from_OraclesElixir_20221206.csv")

# list 저장
df_list = [data20,data21,data22]

# 합침
data_clean = pd.concat(df_list, ignore_index = True)
# Out:
# C:\Users\rladb\AppData\Local\Temp\ipykernel_19332\119226476.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data22 = pd.read_csv("C:\\Users\\rladb\\Desktop\\2022년 2학기\\머신러닝\\ML_Project\\2022_LoL_esports_match_data_from_OraclesElixir_20221206.csv")

# %%
data_clean.head()
# Out:
#                   gameid datacompleteness  \
# 0  ESPORTSTMNT03/1241318         complete
# 1  ESPORTSTMNT03/1241318         complete
# 2  ESPORTSTMNT03/1241318         complete
# 3  ESPORTSTMNT03/1241318         complete
# 4  ESPORTSTMNT03/1241318         complete
#
#                                                  url league  year split  \
# 0  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 1  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 2  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 3  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 4  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
#
#    playoffs                 date  game  patch  ...  opp_csat15 golddiffat15  \
# 0         0  2020-01-03 07:33:26   1.0   9.24  ...       118.0        165.0
# 1         0  2020-01-03 07:33:26   1.0   9.24  ...        98.0       -399.0
# ...

# %%
data_clean.columns
# Out:
# Index(['gameid', 'datacompleteness', 'url', 'league', 'year', 'split',
#        'playoffs', 'date', 'game', 'patch',
#        ...
#        'opp_csat15', 'golddiffat15', 'xpdiffat15', 'csdiffat15', 'killsat15',
#        'assistsat15', 'deathsat15', 'opp_killsat15', 'opp_assistsat15',
#        'opp_deathsat15'],
#       dtype='object', length=123)

# %%
data_clean.hist()
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'playoffs'}>,
#         <AxesSubplot:title={'center':'game'}>,
#         <AxesSubplot:title={'center':'patch'}>,
#         <AxesSubplot:title={'center':'participantid'}>,
#         <AxesSubplot:title={'center':'gamelength'}>,
#         <AxesSubplot:title={'center':'result'}>,
#         <AxesSubplot:title={'center':'kills'}>,
#         <AxesSubplot:title={'center':'deaths'}>,
#         <AxesSubplot:title={'center':'assists'}>],
#        [<AxesSubplot:title={'center':'teamkills'}>,
#         <AxesSubplot:title={'center':'teamdeaths'}>,
#         <AxesSubplot:title={'center':'doublekills'}>,
#         <AxesSubplot:title={'center':'triplekills'}>,
#         <AxesSubplot:title={'center':'quadrakills'}>,
#         <AxesSubplot:title={'center':'pentakills'}>,
#         <AxesSubplot:title={'center':'firstblood'}>,
#         <AxesSubplot:title={'center':'firstbloodkill'}>,
# ...
